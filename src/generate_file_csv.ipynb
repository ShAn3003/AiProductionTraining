# %%
import os
import pandas as pd

def remove_dir_suffix(original_list):
    filtered_list = [element for element in original_list if not element.endswith("dir")]
    return filtered_list

def get_specify_suffix(original_list,str):
    filtered_list = [element for element in original_list if element.endswith(str)]
    return filtered_list

data_dir = '../Data'
file_dir_list = os.listdir(data_dir)
# print(file_dir_list)

target_list = []
label_list = []
for patient in file_dir_list:
    patient_root = os.path.join(data_dir,patient)
    # print(patient_root)
    study_lists = os.listdir(patient_root)
    study_lists = remove_dir_suffix(study_lists)
    # print(study_lists)
    for study in study_lists:
        study_root = os.path.join(patient_root,study)
        # print(study_root)
        series_lists = remove_dir_suffix(os.listdir(study_root))
        for series in series_lists:
            series_root = os.path.join(study_root,series)
            # print(series_root)
            target_lable_list = remove_dir_suffix(os.listdir(series_root))
            # print(target_lable_list)
            dcmi_lists = get_specify_suffix(target_lable_list,"dcm")
            xml_lists = get_specify_suffix(target_lable_list,"xml")
            # print(dcmi_lists)
            # print(xml_lists)
            for dcmi in dcmi_lists:
                dcmi_root = os.path.join(series_root,dcmi)
                index_d,_ = os.path.splitext(dcmi)
                index_d = int(index_d)
                xml_root = "-1"
                for xml in xml_lists:
                    index_x,_ = os.path.splitext(xml)
                    index_x = int(index_x)
                    if index_x ==index_d :
                        xml_root = os.path.join(series_root,xml)
                        break
                target_list.append(dcmi_root)
                label_list.append(xml_root)
                # break
            # break
        # break
    # break
original_df = pd.DataFrame({"target":target_list,"label":label_list})
original_df.to_csv("../datafile.csv",index=False)

# %% [markdown]
# *****
# Well Strucutre By Google Gemini
#
# **Prompt**:
# ```python
# import os
# import pandas as pd
#
# def remove_dir_suffix(original_list):
#     filtered_list = [element for element in original_list if not element.endswith("dir")]
#     return filtered_list
#
# def get_specify_suffix(original_list,str):
#     filtered_list = [element for element in original_list if element.endswith(str)]
#     return filtered_list
#
# data_dir = '../Data'
# file_dir_list = os.listdir(data_dir)
# # print(file_dir_list)
#
# target_list = []
# label_list = []
# for patient in file_dir_list:
#     patient_root = os.path.join(data_dir,patient)
#     # print(patient_root)
#     study_lists = os.listdir(patient_root)
#     study_lists = remove_dir_suffix(study_lists)
#     # print(study_lists)
#     for study in study_lists:
#         study_root = os.path.join(patient_root,study)
#         # print(study_root)
#         series_lists = remove_dir_suffix(os.listdir(study_root))
#         for series in series_lists:
#             series_root = os.path.join(study_root,series)
#             # print(series_root)
#             target_lable_list = remove_dir_suffix(os.listdir(series_root))
#             # print(target_lable_list)
#             dcmi_lists = get_specify_suffix(target_lable_list,"dcm")
#             xml_lists = get_specify_suffix(target_lable_list,"xml")
#             # print(dcmi_lists)
#             # print(xml_lists)
#             for dcmi in dcmi_lists:
#                 dcmi_root = os.path.join(series_root,dcmi)
#                 index_d,_ = os.path.splitext(dcmi)
#                 index_d = int(index_d)
#                 xml_root = "-1"
#                 for xml in xml_lists:
#                     index_x,_ = os.path.splitext(xml)
#                     index_x = int(index_x)
#                     if index_x ==index_d :
#                         xml_root = os.path.join(series_root,xml)
#                         break
#                 target_list.append(dcmi_root)
#                 label_list.append(xml_root)
#                 # break
#             # break
#         # break
#     # break
# original_df = pd.DataFrame({"target":target_list,"label":label_list})
# original_df.to_csv("../datafile.csv",index=False)
# """
# Please make this codesnippet more structure
# """
# ```
# **Respond**:
# ```txt
# The provided code snippet is already fairly well-structured, but here are some improvements for better readability and maintainability:
#
# 1. Descriptive variable names:
#
# Instead of original_list in functions, use file_or_dir_list for clarity.
# Consider matching_suffix for str in get_specify_suffix.
# 2. Docstrings:
#
# Add docstrings to your functions explaining their purpose and parameters.
# 3. Early Termination:
#
# Remove unnecessary nested break statements. Break only after finding the matching XML.
# 4. Logging:
#
# Instead of commented-out print statements, consider using a logging library (e.g., logging) to track progress and potential issues.
# 5. Combining Steps:
#
# Explore combining remove_dir_suffix calls with os.listdir for efficiency (assuming directory suffixes are not needed).
# Here's the improved code with the suggestions:
#
# Python
# import os
# import pandas as pd
#
#
# def remove_dir_suffix(file_or_dir_list):
#     """
#     Filters out entries that end with "dir" (assuming directory suffixes).
#
#     Args:
#         file_or_dir_list: List of filenames or directory names.
#
#     Returns:
#         List containing entries without the "dir" suffix.
#     """
#     return [element for element in file_or_dir_list if not element.endswith("dir")]
#
#
# def get_specify_suffix(file_list, matching_suffix):
#     """
#     Filters a list of files based on a specified suffix.
#
#     Args:
#         file_list: List of filenames.
#         matching_suffix: The suffix to filter by (e.g., "dcm", "xml").
#
#     Returns:
#         List containing entries with the matching suffix.
#     """
#     return [element for element in file_list if element.endswith(matching_suffix)]
#
#
# def process_data_directory(data_dir):
#     """
#     Processes a medical data directory, extracts DICOM-XML pairs, and saves them to a CSV.
#
#     Args:
#         data_dir: Path to the data directory.
#
#     Returns:
#         None (saves results to a CSV file).
#     """
#
#     target_list = []
#     label_list = []
#
#     for patient in os.listdir(data_dir):
#         patient_root = os.path.join(data_dir, patient)
#         study_lists = os.listdir(patient_root)
#
#         for study in study_lists:
#             study_root = os.path.join(patient_root, study)
#             series_lists = os.listdir(study_root)
#
#             for series in series_lists:
#                 series_root = os.path.join(study_root, series)
#                 file_list = os.listdir(series_root)
#
#                 dcmi_lists = get_specify_suffix(file_list, "dcm")
#                 xml_lists = get_specify_suffix(file_list, "xml")
#
#                 for dcmi in dcmi_lists:
#                     dcmi_root = os.path.join(series_root, dcmi)
#                     index_d, _ = os.path.splitext(dcmi)
#                     index_d = int(index_d)
#                     xml_root = "-1"
#
#                     for xml in xml_lists:
#                         index_x, _ = os.path.splitext(xml)
#                         index_x = int(index_x)
#                         if index_x == index_d:
#                             xml_root = os.path.join(series_root, xml)
#                             break
#
#                     target_list.append(dcmi_root)
#                     label_list.append(xml_root)
#
#     original_df = pd.DataFrame({"target": target_list, "label": label_list})
#     original_df.to_csv("../datafile.csv", index=False)
#
#
# if __name__ == "__main__":
#     data_dir = "../Data"
#     process_data_directory(data_dir)
# 请谨慎使用代码。
# content_copy
# This version improves readability and maintainability by using descriptive names, comments, and a docstring for the main processing function.
# ```

# %%
import os
import pandas as pd


def remove_dir_suffix(file_or_dir_list):
    """
    Filters out entries that end with "dir" (assuming directory suffixes).

    Args:
        file_or_dir_list: List of filenames or directory names.

    Returns:
        List containing entries without the "dir" suffix.
    """
    return [element for element in file_or_dir_list if not element.endswith("dir")]


def get_specify_suffix(file_list, matching_suffix):
    """
    Filters a list of files based on a specified suffix.

    Args:
        file_list: List of filenames.
        matching_suffix: The suffix to filter by (e.g., "dcm", "xml").

    Returns:
        List containing entries with the matching suffix.
    """
    return [element for element in file_list if element.endswith(matching_suffix)]


def process_data_directory(data_dir):
    """
    Processes a medical data directory, extracts DICOM-XML pairs, and saves them to a CSV.

    Args:
        data_dir: Path to the data directory.

    Returns:
        None (saves results to a CSV file).
    """

    target_list = []
    label_list = []

    for patient in os.listdir(data_dir):
        patient_root = os.path.join(data_dir, patient)
        study_lists = os.listdir(patient_root)
        study_lists = remove_dir_suffix(study_lists)

        for study in study_lists:
            study_root = os.path.join(patient_root, study)
            series_lists = os.listdir(study_root)
            series_lists = remove_dir_suffix(series_lists)

            for series in series_lists:
                series_root = os.path.join(study_root, series)
                file_list = os.listdir(series_root)
                file_list = remove_dir_suffix(file_list)

                dcmi_lists = get_specify_suffix(file_list, "dcm")
                xml_lists = get_specify_suffix(file_list, "xml")

                for dcmi in dcmi_lists:
                    dcmi_root = os.path.join(series_root, dcmi)
                    index_d, _ = os.path.splitext(dcmi)
                    index_d = int(index_d)
                    xml_root = "-1"

                    for xml in xml_lists:
                        index_x, _ = os.path.splitext(xml)
                        index_x = int(index_x)
                        if index_x == index_d:
                            xml_root = os.path.join(series_root, xml)
                            break

                    target_list.append(dcmi_root)
                    label_list.append(xml_root)

    original_df = pd.DataFrame({"target": target_list, "label": label_list})
    original_df.to_csv("../datafile.csv", index=False)


if __name__ == "__main__":
    data_dir = "../Data"
    process_data_directory(data_dir)
